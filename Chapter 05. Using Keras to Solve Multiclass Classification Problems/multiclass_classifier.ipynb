# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report
import numpy as np
import os

# %%
def load_mnist():
    (train_X, train_y), (test_X, test_y) = mnist.load_data()
    train_X = train_X.reshape(-1, 784)
    test_X = test_X.reshape(-1, 784)
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    train_X /= 255
    test_X /= 255

    train_y = to_categorical(train_y)
    test_y = to_categorical(test_y)
    return {"train_X": train_X[:55000, :], "train_y": train_y[:55000, :],
            "val_X": train_X[55000:, :], "val_y": train_y[55000:, :], "test_X": test_X, "test_y": test_y}

# %%
def build_network(input_features=None):
    # first we specify an input layer, with a shape == features
    inputs = Input(shape=(input_features,), name="input")
    x = Dense(512, activation='relu', name="hidden1")(inputs)
    x = Dense(256, activation='relu', name="hidden2")(x)
    x = Dense(128, activation='relu', name="hidden3")(x)
    prediction = Dense(10, activation='softmax', name="output")(x)
    model = Model(inputs=inputs, outputs=prediction)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
    return model

# %%
def create_callbacks():
    tensorboard_callback = TensorBoard(log_dir=os.path.join(os.getcwd(), "tb_log", "mnist_512_256_128"), histogram_freq=1, batch_size=32,
                                       write_graph=True, write_grads=False)
    checkpoint_callback = ModelCheckpoint(filepath="./model-weights.{epoch:02d}-{val_accuracy:.6f}.hdf5", monitor='val_acc',
                                          verbose=0, save_best_only=True)
    return [tensorboard_callback, checkpoint_callback]

# %%
def print_model_metrics(model, data):
    loss, accuracy = model.evaluate(x=data["test_X"], y=data["test_y"])
    print("\n model test loss is "+str(loss)+" accuracy is "+str(accuracy))

    y_softmax = model.predict(data["test_X"])  # this is an n x class matrix of probabilities
    y_hat = y_softmax.argmax(axis=-1)  # this will be the class number.
    test_y = data["test_y"].argmax(axis=-1)  # our test data is also categorical
    print(classification_report(test_y, y_hat))

# %%
def main():
    data = load_mnist()
    callbacks = create_callbacks()
    model = build_network(data["train_X"].shape[1])
    model.fit(x=data["train_X"], y=data["train_y"],
              batch_size=30,
              epochs=50,
              validation_data=(data["val_X"], data["val_y"]),
              verbose=1,
              callbacks=callbacks)

    print_model_metrics(model, data)

# %%
main()
# Out:
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.
# Epoch 1/50
# 1834/1834 [==============================] - 8s 4ms/step - loss: 0.2011 - accuracy: 0.9383 - val_loss: 0.1361 - val_accuracy: 0.9610
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 2/50
# 1834/1834 [==============================] - 6s 3ms/step - loss: 0.0916 - accuracy: 0.9721 - val_loss: 0.0835 - val_accuracy: 0.9762
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 3/50
# 1834/1834 [==============================] - 6s 3ms/step - loss: 0.0647 - accuracy: 0.9802 - val_loss: 0.0770 - val_accuracy: 0.9788
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 4/50
# 1834/1834 [==============================] - 6s 3ms/step - loss: 0.0508 - accuracy: 0.9839 - val_loss: 0.0870 - val_accuracy: 0.9756
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 5/50
# 1834/1834 [==============================] - 10s 5ms/step - loss: 0.0392 - accuracy: 0.9869 - val_loss: 0.0905 - val_accuracy: 0.9764
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 6/50
# 1834/1834 [==============================] - 11s 6ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.0818 - val_accuracy: 0.9800
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 7/50
# 1834/1834 [==============================] - 11s 6ms/step - loss: 0.0281 - accuracy: 0.9916 - val_loss: 0.0779 - val_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 8/50
# 1834/1834 [==============================] - 11s 6ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.0783 - val_accuracy: 0.9824
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 9/50
# 1834/1834 [==============================] - 11s 6ms/step - loss: 0.0235 - accuracy: 0.9925 - val_loss: 0.0779 - val_accuracy: 0.9840
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 10/50
# 1834/1834 [==============================] - 11s 6ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.0733 - val_accuracy: 0.9846
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 11/50
# 1834/1834 [==============================] - 11s 6ms/step - loss: 0.0205 - accuracy: 0.9938 - val_loss: 0.0745 - val_accuracy: 0.9834
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 12/50
# 1834/1834 [==============================] - 10s 6ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.0906 - val_accuracy: 0.9842
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 13/50
# 1834/1834 [==============================] - 10s 6ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.1000 - val_accuracy: 0.9802
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 14/50
# 1834/1834 [==============================] - 10s 5ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0864 - val_accuracy: 0.9850
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 15/50
# 1834/1834 [==============================] - 12s 6ms/step - loss: 0.0149 - accuracy: 0.9958 - val_loss: 0.0780 - val_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 16/50
# 1834/1834 [==============================] - 12s 6ms/step - loss: 0.0184 - accuracy: 0.9951 - val_loss: 0.1176 - val_accuracy: 0.9788
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 17/50
# 1834/1834 [==============================] - 8s 4ms/step - loss: 0.0130 - accuracy: 0.9966 - val_loss: 0.0926 - val_accuracy: 0.9850
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 18/50
# 1834/1834 [==============================] - 7s 4ms/step - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.1109 - val_accuracy: 0.9834
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 19/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.1061 - val_accuracy: 0.9816
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 20/50
# 1834/1834 [==============================] - 8s 4ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.1272 - val_accuracy: 0.9822
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 21/50
# 1834/1834 [==============================] - 8s 4ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.1186 - val_accuracy: 0.9846
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 22/50
# 1834/1834 [==============================] - 7s 4ms/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.1483 - val_accuracy: 0.9812
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 23/50
# 1834/1834 [==============================] - 7s 4ms/step - loss: 0.0125 - accuracy: 0.9971 - val_loss: 0.1340 - val_accuracy: 0.9796
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 24/50
# 1834/1834 [==============================] - 10s 5ms/step - loss: 0.0108 - accuracy: 0.9974 - val_loss: 0.1141 - val_accuracy: 0.9858
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 25/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.1059 - val_accuracy: 0.9856
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 26/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.1202 - val_accuracy: 0.9860
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 27/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0131 - accuracy: 0.9967 - val_loss: 0.1143 - val_accuracy: 0.9818
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 28/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.1103 - val_accuracy: 0.9832
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 29/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.1239 - val_accuracy: 0.9834
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 30/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.1632 - val_accuracy: 0.9824
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 31/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0144 - accuracy: 0.9969 - val_loss: 0.1199 - val_accuracy: 0.9860
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 32/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.1410 - val_accuracy: 0.9846
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 33/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0132 - accuracy: 0.9971 - val_loss: 0.1332 - val_accuracy: 0.9838
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 34/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.1481 - val_accuracy: 0.9832
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 35/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0087 - accuracy: 0.9979 - val_loss: 0.1493 - val_accuracy: 0.9832
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 36/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.1525 - val_accuracy: 0.9860
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 37/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0126 - accuracy: 0.9976 - val_loss: 0.1395 - val_accuracy: 0.9852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 38/50
# 1834/1834 [==============================] - 8s 5ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.1514 - val_accuracy: 0.9850
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 39/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0081 - accuracy: 0.9981 - val_loss: 0.1642 - val_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 40/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0124 - accuracy: 0.9977 - val_loss: 0.1749 - val_accuracy: 0.9852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 41/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.1900 - val_accuracy: 0.9816
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 42/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0103 - accuracy: 0.9978 - val_loss: 0.1525 - val_accuracy: 0.9832
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 43/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.1355 - val_accuracy: 0.9852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 44/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0141 - accuracy: 0.9972 - val_loss: 0.1556 - val_accuracy: 0.9828
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 45/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.1712 - val_accuracy: 0.9846
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 46/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0119 - accuracy: 0.9980 - val_loss: 0.1697 - val_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 47/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0091 - accuracy: 0.9982 - val_loss: 0.1751 - val_accuracy: 0.9852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 48/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.1610 - val_accuracy: 0.9844
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 49/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0086 - accuracy: 0.9983 - val_loss: 0.1612 - val_accuracy: 0.9852
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# Epoch 50/50
# 1834/1834 [==============================] - 9s 5ms/step - loss: 0.0080 - accuracy: 0.9985 - val_loss: 0.1881 - val_accuracy: 0.9830
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2412 - accuracy: 0.9810
#
#  model test loss is 0.24116459488868713 accuracy is 0.9810000061988831
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.98      0.98      0.98      1010
#            4       0.97      0.99      0.98       982
#            5       0.98      0.98      0.98       892
#            6       0.99      0.98      0.98       958
#            7       0.98      0.96      0.97      1028
#            8       0.98      0.98      0.98       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
